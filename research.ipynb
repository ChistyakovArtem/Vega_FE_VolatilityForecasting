# %%
import sys
sys.path.append("..")

from utils.testing.testing_pipeline import TestingPipeline
from marketdata.market_data import MarketData
from utils.testing.target_functions import NextAbsReturn, NextSquaredReturn
from utils.volatility_models.base_prediction_model import *

configs = [
    {
        "stock": "AAPL",
        "period": "5y",
        "interval": "1d",
    },
    {
        "stock": "MSFT",
        "period": "5y",
        "interval": "1d",
    },
    {
        "stock": "GOOGL",
        "period": "5y",
        "interval": "1d",
    },
    {
        "stock": "AMZN",
        "period": "5y",
        "interval": "1d",
    },
    {
        "stock": "AAPL",
        "period": "5d",
        "interval": "1m",
    },
    {
        "stock": "MSFT",
        "period": "5d",
        "interval": "1m",
    },
    {
        "stock": "GOOGL",
        "period": "5d",
        "interval": "1m",
    },
    {
        "stock": "AMZN",
        "period": "5d",
        "interval": "1m",
    }
]

# %%
pipeline = TestingPipeline(
    marketdata_list=[MarketData(yahoo_params=cfg) for cfg in configs],
    target_function=NextSquaredReturn(),
    prediction_model=NaivePredictionModel(NextAbsReturn()),
)

naive_results = pipeline.run()
naive_results
# Out:
# [('Data: AAPL_5y_1d, Target: Next Squared Return, Model: Naive Prediction Model',
#   0.11378298184059903,
#   253),
#  ('Data: MSFT_5y_1d, Target: Next Squared Return, Model: Naive Prediction Model',
#   -0.07835770229381982,
#   253),
#  ('Data: GOOGL_5y_1d, Target: Next Squared Return, Model: Naive Prediction Model',
#   0.039683788992707,
#   253),
#  ('Data: AMZN_5y_1d, Target: Next Squared Return, Model: Naive Prediction Model',
#   0.1514119630536745,
#   253),
#  ('Data: AAPL_5d_1m, Target: Next Squared Return, Model: Naive Prediction Model',
#   0.06032050038518333,
#   315),
#  ('Data: MSFT_5d_1m, Target: Next Squared Return, Model: Naive Prediction Model',
#   0.10152385583863462,
#   315),
#  ('Data: GOOGL_5d_1m, Target: Next Squared Return, Model: Naive Prediction Model',
#   0.3981760323594309,
#   315),
#  ('Data: AMZN_5d_1m, Target: Next Squared Return, Model: Naive Prediction Model',
#   0.06538844719175477,
#   315)]

# %%
pipeline = TestingPipeline(
    marketdata_list=[MarketData(yahoo_params=cfg) for cfg in configs],
    target_function=NextSquaredReturn(),
    prediction_model=AR(NextSquaredReturn(), lag=5) 
)

ar_results = pipeline.run()
ar_results
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# ...

# %%
pipeline = TestingPipeline(
    marketdata_list=[MarketData(yahoo_params=cfg) for cfg in configs],
    target_function=NextSquaredReturn(),
    prediction_model=GARCHPredictionModel(NextSquaredReturn(), lag=5)
)

garch_results = pipeline.run()
garch_results
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2019-12-02 00:00:00-05:00   64.778412   65.015938   63.852562   64.024643
# 2019-12-03 00:00:00-05:00   62.606758   62.902451   62.117172   62.883064
# 2019-12-04 00:00:00-05:00   63.275692   63.818600   63.181164   63.438076
# 2019-12-05 00:00:00-05:00   63.934967   64.443947   63.678054   64.368805
# 2019-12-06 00:00:00-05:00   64.829292   65.682434   64.785660   65.612144
# ...                               ...         ...         ...         ...
# 2024-11-25 00:00:00-05:00  231.460007  233.250000  229.740005  232.869995
# 2024-11-26 00:00:00-05:00  233.330002  235.570007  233.330002  235.059998
# 2024-11-27 00:00:00-05:00  234.470001  235.690002  233.809998  234.929993
# 2024-11-29 00:00:00-05:00  234.809998  237.809998  233.970001  237.330002
# 2024-12-02 00:00:00-05:00  237.270004  240.789993  237.160004  239.910004
#
#                               Volume  Dividends  Stock Splits       price
# ...
